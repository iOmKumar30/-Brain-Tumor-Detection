# %% [markdown]
# # 3D UNet Baseline
#
# This notebook is intentionally lightweight. Training logic lives in `src/brats_ai` so experiments are reproducible from CLI, API, and notebooks without hidden state.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if (ROOT / 'src').exists():
    sys.path.insert(0, str(ROOT / 'src'))
else:
    sys.path.insert(0, str(ROOT.parent / 'src'))

from brats_ai.config import ExperimentConfig, validate_config

config = ExperimentConfig()
validate_config(config)

# %% [markdown]
# ## Train
#
# Run the baseline after preparing data according to `docs/DATASET.md`.

# %%
print('Dry run: python -m brats_ai.cli.train --config configs/default.yaml --dry-run')
print('Train:   python -m brats_ai.cli.train --config configs/default.yaml')
